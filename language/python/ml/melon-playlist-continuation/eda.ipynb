# %%
import glob
import json
import os
import re
import numpy as np
import pandas as pd
import nltk
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

from nltk.corpus import stopwords
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from pandas.plotting import register_matplotlib_converters

# %%
genre_df = pd.read_json('data/genre_gn_all.json', orient='index').reset_index().rename(columns={'index':'gnr_code', 0:'gnr_name'})
display(genre_df)

meta_df = pd.read_json('data/song_meta.json', typ = 'frame')
display(meta_js)

train_df = pd.read_json('data/train.json', typ = 'frame')
display(train_df)

valid_df = pd.read_json('data/valid.json', typ = 'frame')
display(valid_df)
# Out:
#     gnr_code gnr_name
# 0     GN0100      발라드
# 1     GN0101   세부장르전체
# 2     GN0102      '80
# 3     GN0103      '90
# 4     GN0104      '00
# ..       ...      ...
# 249   GN2900      뮤지컬
# 250   GN2901   세부장르전체
# 251   GN2902    국내뮤지컬
# 252   GN2903    국외뮤지컬
# 253   GN3000    크리스마스
#
# [254 rows x 2 columns]
#        song_gn_dtl_gnr_basket  issue_date  \
# 0                    [GN0901]    20140512
# 1            [GN1601, GN1606]    20080421
# 2                    [GN0901]    20180518
# 3            [GN1102, GN1101]    20151016
# 4            [GN1802, GN1801]    20110824
# ...                       ...         ...
# 707984               [GN2001]    19991219
# 707985               [GN0901]    19860000
# 707986       [GN0105, GN0101]    20160120
# 707987       [GN1807, GN1801]    20131217
# 707988       [GN0601, GN0604]    19980000
#
#                                                album_name  album_id  \
# 0                            불후의 명곡 - 7080 추억의 얄개시대 팝송베스트   2255639
# ...

# %%
plylst_song_map = train[['id', 'songs']]

# unnest songs
plylst_song_map_unnest = np.dstack(
    (
        np.repeat(plylst_song_map.id.values, list(map(len, plylst_song_map.songs))), 
        np.concatenate(plylst_song_map.songs.values)
    )
)

# unnested 데이터프레임 생성 : plylst_song_map
plylst_song_map = pd.DataFrame(data = plylst_song_map_unnest[0], columns = plylst_song_map.columns)
plylst_song_map['id'] = plylst_song_map['id'].astype(str)
plylst_song_map['songs'] = plylst_song_map['songs'].astype(str)

# unnest 객체 제거
del plylst_song_map_unnest
