# %%
import PIL
from PIL import Image
import numpy as np

# %%
dog_pl = Image.open('data/dog.jpg')
display(dog_pl.resize((200, 200), Image.ANTIALIAS))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FB8315A9610>

# %%
dog_np = np.asarray(dog_pl)
display(dog_np.shape)
Image.fromarray(dog_np[:,:,0]).resize((200, 200))
# Out:
# (638, 640, 3)
# <PIL.Image.Image image mode=L size=200x200 at 0x7FB8357B7890>
